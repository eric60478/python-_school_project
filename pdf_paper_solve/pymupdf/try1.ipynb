# %%
import requests
from datetime import datetime
# import sqlite3 # fot sqlute database support
from bs4 import BeautifulSoup

# %%
import urllib.request as request
src="https://www.facebook.com/"
with request.urlopen(src)as response:
    data=response.read().decode("utf-8")
print(data)
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant" id="facebook" class="no_js">
# ...

# %%
import requests
response = requests.get('https://www.youtube.com/watch?v=sUzR3QVBKIo&t=0s')
# Out:
# 200

# %%
from selenium import webdriver
# 透過Browser Driver 開啟 Chrome
driver = webdriver.Chrome(r"C:\\Users\\GIGABYTE\\Python_Homework_Save\\python homework\\專題作業\\chromedriver_win32\\chromedriver")
# 前往特定網址
default_url = "http://www.google.com"
driver.get(default_url)
# 定位搜尋框
element = driver.find_element_by_class_name("gLFyf.gsfi")
# 傳入字串
element.send_keys("Selenium Python")
# Out:
# <ipython-input-8-4b0d4a4c3f24>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\\Users\\GIGABYTE\\Python_Homework_Save\\python homework\\專題作業\\chromedriver_win32\\chromedriver")
# <ipython-input-8-4b0d4a4c3f24>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element = driver.find_element_by_class_name("gLFyf.gsfi")
